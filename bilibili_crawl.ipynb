# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.indeed.com/jobs?q=Data+Analyst&l=Chicago%2C+IL&radius=50&fromage=7'

# %%
response = requests.get(url)
html_text = response.text
soup = BeautifulSoup(html_text,'html.parser')

# %%
body = soup.find('td')

# %%
items = body.find_all('div',class_='jobsearch-SerpJobCard unifiedRow row result clickcard')

# %%
items
# Out:
# []

# %%
for i in items:
# Out:
# [<td width=""><table cellpadding="0" cellspacing="0" class="embedded-labels-what-where-test lnav" role="navigation">
#  <tr class="">
#  <td style="padding-top:3px;" valign="top">
#  <form action="/jobs" class="jsf" id="jobsearch" method="get" name="js" onsubmit="ptk('topsearch');submitAutocompleteLog();">
#  <table align="left" cellpadding="3" cellspacing="0" role="presentation">
#  <tr role="search">
#  <td>
#  <div class="jobsearch-EmbeddedLabelInput" id="what_container">
#  <div class="jobsearch-EmbeddedLabelInput-wrapper"><label class="jobsearch-EmbeddedLabelInput-label" for="what" id="embedded_what_label_top">What</label>
#  <input aria-label="what: job title, keywords, or company" autocomplete="off" class="jobsearch-EmbeddedLabelInput-input input_text" id="what" maxlength="512" name="q" placeholder="Job title, keywords, or company" value="Data Analyst"/>
#  </div><div style="width:340px"><!-- --></div>
# ...

# %%
<div class="jobsearch-SerpJobCard unifiedRow row result clickcard" id="p_43b8cd0736a53a26" data-jk="43b8cd0736a53a26" data-tn-component="organicJob">

<h2 class="title">
<a target="_blank" id="jl_43b8cd0736a53a26" href="/rc/clk?jk=43b8cd0736a53a26&amp;fccid=5ee084757f8a188d&amp;vjs=3" onmousedown="return rclk(this,jobmap[1],0);" onclick="setRefineByCookie(['radius']); return rclk(this,jobmap[1],true,0);" rel="noopener nofollow" title="Data Analyst, The Core" class="jobtitle turnstileLink " data-tn-element="jobTitle">
<b>Data</b> <b>Analyst</b>, The Core</a>

<span class="new">new</span></h2>

<div class="sjcl">
<div>
<span class="company">
<a data-tn-element="companyName" class="turnstileLink" target="_blank" href="/cmp/Leo-Burnett" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=&amp;fromjk=43b8cd0736a53a26&amp;jcid=5ee084757f8a188d')" rel="noopener">
Leo Burnett</a></span>

<span class="ratingsDisplay">
<a data-tn-variant="cmplinktst2" class="ratingNumber" href="/cmp/Leo-Burnett/reviews" title="Leo Burnett reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Analyst%2C+The+Core&amp;fromjk=43b8cd0736a53a26&amp;jcid=5ee084757f8a188d');" target="_blank" rel="noopener">
<span class="ratingsContent">
4.1<svg width="12px" height="12px" role="img" class="starIcon">
<g>
<path style="fill: #FFB103" d="M 12.00,4.34 C 12.00,4.34 7.69,3.97 7.69,3.97 7.69,3.97 6.00,0.00 6.00,0.00 6.00,0.00 4.31,3.98 4.31,3.98 4.31,3.98 0.00,4.34 0.00,4.34 0.00,4.34 3.28,7.18 3.28,7.18 3.28,7.18 2.29,11.40 2.29,11.40 2.29,11.40 6.00,9.16 6.00,9.16 6.00,9.16 9.71,11.40 9.71,11.40 9.71,11.40 8.73,7.18 8.73,7.18 8.73,7.18 12.00,4.34 12.00,4.34 Z"></path>
</g>
</svg>
</span>
</a>
</span>
</div>
<div id="recJobLoc_43b8cd0736a53a26" class="recJobLoc" data-rc-loc="Chicago, IL" style="display: none"></div>
<span class="location accessible-contrast-color-location">Chicago, IL</span>
</div>

<div class="summary">
<ul style="list-style-type:circle;margin-top: 0px;margin-bottom: 0px;padding-left:20px;"> 
 <li style="margin-bottom:0px;">Experience using <b>data</b> analytic tools, like the following, is preferred:</li>
 <li>Become a storyteller with our Clients' <b>data</b>, working to uncover deep analytical insights…</li>
</ul></div>

<div class="jobsearch-SerpJobCard-footer">
<div class="jobsearch-SerpJobCard-footerActions">

<div class="result-link-bar-container">
<div class="result-link-bar"><span class="date ">2 days ago</span><span id="tt_set_1" class="tt_set"><div class="job-reaction"><button class="job-reaction-kebab" aria-haspopup="true" aria-expanded="false" data-ol-has-click-handler="" tabindex="0" aria-label="save or dislike" onclick="toggleKebabMenu('43b8cd0736a53a26', false, event); return false;"></button><span class="job-reaction-kebab-menu"><button class="job-reaction-kebab-item job-reaction-save" onclick="changeJobState('43b8cd0736a53a26', 'save', 'linkbar', false, '');return false;" data-ol-has-click-handler=""><svg focusable="false" viewBox="0 0 24 24" height="16" width="16"><g><path fill="#2d2d2d" d="M16.5,3A6,6,0,0,0,12,5.09,6,6,0,0,0,7.5,3,5.45,5.45,0,0,0,2,8.5C2,12.28,5.4,15.36,10.55,20L12,21.35,13.45,20C18.6,15.36,22,12.28,22,8.5A5.45,5.45,0,0,0,16.5,3ZM12.1,18.55l-0.1.1-0.1-.1C7.14,14.24,4,11.39,4,8.5A3.42,3.42,0,0,1,7.5,5a3.91,3.91,0,0,1,3.57,2.36h1.87A3.88,3.88,0,0,1,16.5,5,3.42,3.42,0,0,1,20,8.5C20,11.39,16.86,14.24,12.1,18.55Z"></path></g></svg><span class="job-reaction-kebab-item-text">Save job</span></button><button class="job-reaction-kebab-item job-reaction-dislike" onclick="dislikeJob(false, false, '43b8cd0736a53a26', 'unsave', 'linkbar', false, '');" data-ol-has-click-handler=""><span class="job-reaction-dislike-icon"></span><span class="job-reaction-kebab-item-text">Not interested</span></button><button class="job-reaction-kebab-item job-reaction-report" onclick="reportJob('43b8cd0736a53a26');"><span class="job-reaction-report-icon"></span><span class="job-reaction-kebab-item-text">Report Job</span></button></span></div><span class="result-link-bar-separator">·</span><button id="tog_1" class="sl resultLink more-link " onclick="toggleMoreLinks('43b8cd0736a53a26', '1'); return false;" aria-expanded="false">More...</button></span><div id="editsaved2_43b8cd0736a53a26" class="edit_note_content" style="display:none;"></div><script>if (!window['result_43b8cd0736a53a26']) {window['result_43b8cd0736a53a26'] = {};}window['result_43b8cd0736a53a26']['showSource'] = false; window['result_43b8cd0736a53a26']['source'] = "Leo Burnett"; window['result_43b8cd0736a53a26']['loggedIn'] = true; window['result_43b8cd0736a53a26']['showMyJobsLinks'] = true;window['result_43b8cd0736a53a26']['undoAction'] = "unsave";window['result_43b8cd0736a53a26']['relativeJobAge'] = "2 days ago";window['result_43b8cd0736a53a26']['jobKey'] = "43b8cd0736a53a26"; window['result_43b8cd0736a53a26']['myIndeedAvailable'] = true; window['result_43b8cd0736a53a26']['showMoreActionsLink'] = window['result_43b8cd0736a53a26']['showMoreActionsLink'] || true; window['result_43b8cd0736a53a26']['resultNumber'] = 1; window['result_43b8cd0736a53a26']['jobStateChangedToSaved'] = false; window['result_43b8cd0736a53a26']['searchState'] = "q=Data Analyst&amp;l=Chicago%2C+IL&amp;radius=50&amp;fromage=7"; window['result_43b8cd0736a53a26']['basicPermaLink'] = "https://www.indeed.com"; window['result_43b8cd0736a53a26']['saveJobFailed'] = false; window['result_43b8cd0736a53a26']['removeJobFailed'] = false; window['result_43b8cd0736a53a26']['requestPending'] = false; window['result_43b8cd0736a53a26']['notesEnabled'] = true; window['result_43b8cd0736a53a26']['currentPage'] = "serp"; window['result_43b8cd0736a53a26']['sponsored'] = false;window['result_43b8cd0736a53a26']['reportJobButtonEnabled'] = false; window['result_43b8cd0736a53a26']['showMyJobsHired'] = true; window['result_43b8cd0736a53a26']['showSaveForSponsored'] = false; window['result_43b8cd0736a53a26']['showJobAge'] = true; window['result_43b8cd0736a53a26']['showHolisticCard'] = true; window['result_43b8cd0736a53a26']['showDislike'] = true; window['result_43b8cd0736a53a26']['showKebab'] = true; window['result_43b8cd0736a53a26']['showReport'] = true;</script></div></div>
</div>
</div>


<div class="tab-container">
<div id="tt_display_1" class="more-links-container result-tab" style="display:none;"><div id="more_1" class="more_actions"><ul><li><span class="mat">View all <a href="/q-Leo-Burnett-l-Chicago,-IL-jobs.html">Leo Burnett jobs in Chicago, IL</a> - <a href="/l-Chicago,-IL-jobs.html">Chicago jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salaries/data-analyst-Salaries,-Chicago-IL" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=serp-more&amp;fromjk=43b8cd0736a53a26&amp;from=serp-more');">Data Analyst salaries in Chicago, IL</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/Leo-Burnett/about" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=43b8cd0736a53a26&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=5ee084757f8a188d');">Leo Burnett</a></span></li><li><span class="mat">See popular <a href="/cmp/Leo-Burnett/faq" onmousedown="this.href = appendParamsOnce(this.href, '?from=serp-more&amp;campaignid=serp-more&amp;fromjk=43b8cd0736a53a26&amp;jcid=5ee084757f8a188d');">questions &amp; answers about Leo Burnett</a></span></li><li><span class="mat">Explore career as Data Analyst: <a href="/career/data-analyst" onmousedown="this.href = appendParamsOnce(this.href, 'from=jasx');">overview</a>, <a href="/career/data-analyst/career-advice" onmousedown="this.href = appendParamsOnce(this.href, 'from=jasx');">career advice</a>, <a href="/career/data-analyst/faq" onmousedown="this.href = appendParamsOnce(this.href, 'from=jasx');">FAQs</a></span></li></ul></div><a class="close-link closeLink" title="Close" href="#" onclick="toggleMoreLinks('43b8cd0736a53a26'); return false;"></a></div><div class="dya-container result-tab"></div>
<div class="tellafriend-container result-tab email_job_content"></div>
<div class="sign-in-container result-tab"></div>
<div class="notes-container result-tab"></div>
</div>
</div>
